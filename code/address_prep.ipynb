# %%
# prepare packages
import pandas as pd

# %%
# load data
addresses = pd.read_csv('../data/us_addresses.csv')

# %%
addresses[addresses['state_name'] == 'Maryland'][['city']]
# Out:
#                 city
# 12           Ellicot
# 15      Gaithesburg,
# 44        Colesville
# 53          Perryman
# 95      District Hts
# ...              ...
# 18460      Suiteland
# 18468        Elliott
# 18474      Glen Echo
# 18483   Leonard Town
# 18495  New Carrolltn
#
# [1155 rows x 1 columns]

# %%
addresses.loc[addresses['state_name'] == 'Maryland'][['city']]
# Out:
#                 city
# 12           Ellicot
# 15      Gaithesburg,
# 44        Colesville
# 53          Perryman
# 95      District Hts
# ...              ...
# 18460      Suiteland
# 18468        Elliott
# 18474      Glen Echo
# 18483   Leonard Town
# 18495  New Carrolltn
#
# [1155 rows x 1 columns]

# %%
api = pd.read_csv('../data/api_distance_results.csv')

# %%
cali = addresses.loc[addresses['state_name'] == 'California']

# %%
cali
# Out:
#                     city  state_name
# 3         South Pasedena  California
# 21        Shingle Spring  California
# 22            Arcata, Ca  California
# 39         Marina Dl Rey  California
# 58     Fpo San Francisco  California
# ...                  ...         ...
# 18465          Escondido  California
# 18475    Palos Verdes Es  California
# 18476      Arroyo Grande  California
# 18485             Santee  California
# 18486      Grand Terrace  California
#
# [1081 rows x 2 columns]

# %%
pd.merge(cali, api, how = 'inner', on=['city','state_name'])
# Out:
#                 city  state_name   country_name   latitude   longitude  \
# 0     Shingle Spring  California  United States  38.671387 -120.940545
# 1         Arcata, Ca  California  United States  40.866517 -124.082840
# 2         San Carlos  California  United States  37.504936 -122.261824
# 3         Gold River  California  United States  38.624845 -121.247461
# 4    El Dorado Hills  California  United States  38.677168 -121.064320
# ..               ...         ...            ...        ...         ...
# 901         Montrose  California  United States  34.206418 -118.228889
# 902        Escondido  California  United States  33.121675 -117.081485
# 903    Arroyo Grande  California  United States  35.118587 -120.590725
# 904           Santee  California  United States  32.838383 -116.973917
# 905    Grand Terrace  California  United States  34.033903 -117.313654
#
#      nyc_distance  dc_distance
# 0     2475.560371  2346.856343
# 1     2589.167355  2474.014535
# ...

# %%
hist_df = addresses.groupby(['state_name']).count().sort_values('city', ascending=False).head(20)

# %%
hist_df
# Out:
#                 city
# state_name
# New York        1551
# Pennsylvania    1415
# Maryland        1154
# California      1080
# Virginia        1073
# New Jersey       920
# Florida          656
# Massachusetts    630
# Ohio             619
# Illinois         575
# Texas            571
# North Carolina   533
# Michigan         516
# Minnesota        360
# Maine            358
# Wisconsin        350
# Georgia          327
# Connecticut      320
# Washington       312
# Vermont          284

# %%
hist_df.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
hist_df = hist_df.rename(columns={'city':'city_count'})

# %%
# Out:
#                 city_count
# state_name
# New York              1551
# Pennsylvania          1415
# Maryland              1154
# California            1080
# Virginia              1073
# New Jersey             920
# Florida                656
# Massachusetts          630
# Ohio                   619
# Illinois               575
# Texas                  571
# North Carolina         533
# Michigan               516
# Minnesota              360
# Maine                  358
# Wisconsin              350
# Georgia                327
# Connecticut            320
# Washington             312
# Vermont                284
